# %% [markdown]
# # HealthConnect AI - Prompt Engineering
#
# Experiment with different prompts for the conversation agent.

# %%
import sys
sys.path.append('..')

from config.prompts.system_prompts import CONVERSATION_AGENT_PROMPT
from config.prompts.prompt_templates import RAGPromptTemplate

# Display system prompt
print("=== Conversation Agent System Prompt ===")
print(CONVERSATION_AGENT_PROMPT[:500])
print("...")

# Test RAG prompt template
rag_prompt = RAGPromptTemplate.SYSTEM_PROMPT.format(
    context="HealthConnect Clinic is located at 123 Main Street. Hours: Mon-Fri 8am-6pm.",
    query="Where are you located?",
)

print("\n=== RAG Prompt Example ===")
print(rag_prompt)
